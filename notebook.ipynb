# %% [markdown]
# Notebook that is used for showing generated objects (random line, triangle and square)

# %%
import random as rn
import numpy as np
import math
import matplotlib.pyplot as plt
from PIL import Image
# %load_ext autoreload
# %autoreload 1
# %aimport gen_funcs
from gen_funcs import*
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
line_1 = gen_line(1000)
imgplot_1 = plt.imshow(line_1)

# %%
circle_1 = gen_circle(100)
imgplot_2 = plt.imshow(circle_1)

# %%
square_1 = gen_square(100)
img_plot_3 = plt.imshow(square_1)

# %%
triangle_1 = gen_eqi_triangle(100)
img_plot_4 = plt.imshow(triangle_1)

# %%
triangle_ran = gen_triangle(100)
img_plot_5 = plt.imshow(triangle_ran)
